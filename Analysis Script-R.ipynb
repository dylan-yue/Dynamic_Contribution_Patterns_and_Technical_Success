# %%
# Model 1
library(lmerTest)
library(sjstats)

modify = read.csv("Data/Whole_sample.csv", header = TRUE, sep = ",")
model0 = lmer(centrality~(1|project), data = modify)
# summary(model0)

model1 = lmer(centrality~gender+ecosystem1+ecosystem2+(1|project), data = modify)
# summary(model1)

model2 = lmer(centrality~MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.slope.
              +MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_5__attr_.slope.
              +MODIFY__approximate_entropy__m_2__r_0.1
              +MODIFY__c3__lag_1
              +MODIFY__c3__lag_2
              +MODIFY__c3__lag_3
              +MODIFY__cid_ce__normalize_False
              +MODIFY__count_below__t_0
              +MODIFY__energy_ratio_by_chunks__num_segments_10__segment_focus_0
              +MODIFY__first_location_of_maximum
              +MODIFY__large_standard_deviation__r_0.2
              +MODIFY__longest_strike_above_mean
              +MODIFY__longest_strike_below_mean
              +MODIFY__mean_change
              +MODIFY__percentage_of_reoccurring_datapoints_to_all_datapoints
              +MODIFY__quantile__q_0.9
              +MODIFY__ratio_value_number_to_time_series_length
              +MODIFY__sample_entropy
              +MODIFY__sum_of_reoccurring_data_points
              +MODIFY__symmetry_looking__r_0.05
              +MODIFY__time_reversal_asymmetry_statistic__lag_1
              +MODIFY__time_reversal_asymmetry_statistic__lag_2
              +MODIFY__time_reversal_asymmetry_statistic__lag_3
              +MODIFY__variance
              +gender
              +ecosystem1
              +ecosystem2
              +(1|project), 
              data = modify)
summary(model2)

performance::r2(model2)

# %%
# Apache ecosystem
# Model 2
# Samples with ecosystem1==0 and ecosystem2==0
library(lmerTest)

modify = read.csv("Data/Whole_sample.csv", header = TRUE, sep = ",")
modify = modify[modify$ecosystem1==0 & modify$ecosystem2==0,]

model0 = lmer(centrality~(1|project), data = modify)
# summary(model0)

model1 = lmer(centrality~gender+(1|project), data = modify)
# summary(model1)

model2 = lmer(centrality~MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.slope.
              +MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_5__attr_.slope.
              +MODIFY__approximate_entropy__m_2__r_0.1
              +MODIFY__c3__lag_1
              +MODIFY__c3__lag_2
              +MODIFY__c3__lag_3
              +MODIFY__cid_ce__normalize_False
              +MODIFY__count_below__t_0
              +MODIFY__energy_ratio_by_chunks__num_segments_10__segment_focus_0
              +MODIFY__first_location_of_maximum
              +MODIFY__large_standard_deviation__r_0.2
              +MODIFY__longest_strike_above_mean
              +MODIFY__longest_strike_below_mean
              +MODIFY__mean_change
              +MODIFY__percentage_of_reoccurring_datapoints_to_all_datapoints
              +MODIFY__quantile__q_0.9
              +MODIFY__ratio_value_number_to_time_series_length
              +MODIFY__sample_entropy
              +MODIFY__sum_of_reoccurring_data_points
              +MODIFY__symmetry_looking__r_0.05
              +MODIFY__time_reversal_asymmetry_statistic__lag_1
              +MODIFY__time_reversal_asymmetry_statistic__lag_2
              +MODIFY__time_reversal_asymmetry_statistic__lag_3
              +MODIFY__variance
              +gender
              +(1|project), 
              data = modify)
summary(model2)

performance::r2(model2)

# %%
# OpenStack ecosystem
# Model 3
# Samples with ecosystem1==1 and ecosystem2==1
library(lmerTest)

modify = read.csv("Data/Whole_sample.csv", header = TRUE, sep = ",")
modify <- modify[modify$ecosystem1==1 & modify$ecosystem2==1,]

model0 = lmer(centrality~(1|project), data = modify)
# summary(model0)

model1 = lmer(centrality~gender+(1|project), data = modify)
# summary(model1)

model2 = lmer(centrality~MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.slope.
              +MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_5__attr_.slope.
              +MODIFY__approximate_entropy__m_2__r_0.1
              +MODIFY__c3__lag_1
              +MODIFY__c3__lag_2
              +MODIFY__c3__lag_3
              +MODIFY__cid_ce__normalize_False
              +MODIFY__count_below__t_0
              +MODIFY__energy_ratio_by_chunks__num_segments_10__segment_focus_0
              +MODIFY__first_location_of_maximum
              +MODIFY__large_standard_deviation__r_0.2
              +MODIFY__longest_strike_above_mean
              +MODIFY__longest_strike_below_mean
              +MODIFY__mean_change
              +MODIFY__percentage_of_reoccurring_datapoints_to_all_datapoints
              +MODIFY__quantile__q_0.9
              +MODIFY__ratio_value_number_to_time_series_length
              +MODIFY__sample_entropy
              +MODIFY__sum_of_reoccurring_data_points
              +MODIFY__symmetry_looking__r_0.05
              +MODIFY__time_reversal_asymmetry_statistic__lag_1
              +MODIFY__time_reversal_asymmetry_statistic__lag_2
              +MODIFY__time_reversal_asymmetry_statistic__lag_3
              +MODIFY__variance
              +gender
              +ecosystem1
              +ecosystem2
              +(1|project), 
              data = modify)
summary(model2)

performance::r2(model2)

# %%
# Data Science ecosystem
# Model 4
# Samples with ecosystem1==1 and ecosystem2==0
library(lmerTest)

modify = read.csv("Data/Whole_sample.csv", header = TRUE, sep = ",")
modify <- modify[modify$ecosystem1==1 & modify$ecosystem2==0,]
model0 = lmer(centrality~(1|project), data = modify)
# summary(model0)

model1 = lmer(centrality~gender+(1|project), data = modify)
# summary(model1)

model2 = lmer(centrality~MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.slope.
              +MODIFY__agg_linear_trend__f_agg_.max.__chunk_len_5__attr_.slope.
              +MODIFY__approximate_entropy__m_2__r_0.1
              +MODIFY__c3__lag_1
              +MODIFY__c3__lag_2
              +MODIFY__c3__lag_3
              +MODIFY__cid_ce__normalize_False
              +MODIFY__count_below__t_0
              +MODIFY__energy_ratio_by_chunks__num_segments_10__segment_focus_0
              +MODIFY__first_location_of_maximum
              +MODIFY__large_standard_deviation__r_0.2
              +MODIFY__longest_strike_above_mean
              +MODIFY__longest_strike_below_mean
              +MODIFY__mean_change
              +MODIFY__percentage_of_reoccurring_datapoints_to_all_datapoints
              +MODIFY__quantile__q_0.9
              +MODIFY__ratio_value_number_to_time_series_length
              +MODIFY__sample_entropy
              +MODIFY__sum_of_reoccurring_data_points
              +MODIFY__symmetry_looking__r_0.05
              +MODIFY__time_reversal_asymmetry_statistic__lag_1
              +MODIFY__time_reversal_asymmetry_statistic__lag_2
              +MODIFY__time_reversal_asymmetry_statistic__lag_3
              +MODIFY__variance
              +gender
              +ecosystem1
              +ecosystem2
              +(1|project), 
              data = modify)
summary(model2)

performance::r2(model2)
